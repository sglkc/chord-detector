# %% [markdown]
# # Compare CNN: clean vs noise features
#
# Evaluate the **fixed training-domain CNN** on clean and noise-mixed cross-domain packs (**vivo / thinkpad / flow / thinkpad-2 / flow-2 / thinkpad-2 / flow-2**).
#
# - Training features are **not** mixed; model is the baseline `model-bn-c64-c128-c256-c256-d256.keras`.
# - **flow** = original ROG Flow evaluation set (`evaluations/test-all`, linked as `datasets/flow` + `features/flow.npz`).
# - Predictions and metrics are **cached** under `cnn-compare-results/` so a crash mid-run can resume.
# - Set `FORCE_REEVAL = True` to recompute everything.

# %% [markdown]
# ## Config

# %%
from os import path
import pandas as pd
from IPython.display import display

# --- paths ---
FEATURES_DIR = path.normpath("../../features")
MODEL_PATH = path.normpath("../../models/model-bn-c64-c128-c256-c256-d256.keras")
RESULTS_DIR = path.normpath("./cnn-compare-results")
CACHE_DIR = path.join(RESULTS_DIR, "cache")
METRICS_DIR = path.join(RESULTS_DIR, "metrics")
SUMMARY_PATH = path.join(RESULTS_DIR, "summary.csv")
PERCLASS_PATH = path.join(RESULTS_DIR, "perclass_comparison.csv")
PROGRESS_PATH = path.join(RESULTS_DIR, "progress.csv")

# Canonical class order from training labels
TRAINING_FEATURES = path.join(FEATURES_DIR, "training.npz")

# Eval packs: clean + noise for each cross-domain set
# flow = ROG Flow paper/eval pack (test-all)
EVAL_SETS = [
    {"name": "vivo_clean", "domain": "vivo", "variant": "clean",
     "features": "vivo.npz"},
    {"name": "vivo_noise", "domain": "vivo", "variant": "noise",
     "features": "vivo-noise-interior_domestic.npz"},
    {"name": "thinkpad_clean", "domain": "thinkpad", "variant": "clean",
     "features": "thinkpad.npz"},
    {"name": "thinkpad_noise", "domain": "thinkpad", "variant": "noise",
     "features": "thinkpad-noise-interior_domestic.npz"},
    {"name": "flow_clean", "domain": "flow", "variant": "clean",
     "features": "flow.npz"},
    {"name": "flow_noise", "domain": "flow", "variant": "noise",
     "features": "flow-noise-interior_domestic.npz"},
    {"name": "thinkpad-2_clean", "domain": "thinkpad-2", "variant": "clean",
     "features": "thinkpad-2.npz"},
    {"name": "thinkpad-2_noise", "domain": "thinkpad-2", "variant": "noise",
     "features": "thinkpad-2-noise-interior_domestic.npz"},
    {"name": "flow-2_clean", "domain": "flow-2", "variant": "clean",
     "features": "flow-2.npz"},
    {"name": "flow-2_noise", "domain": "flow-2", "variant": "noise",
     "features": "flow-2-noise-interior_domestic.npz"},
]

FORCE_REEVAL = False  # True = ignore caches and re-predict
BATCH_SIZE = 16
RANDOM_STATE = 42
TF_CPP_MIN_LOG_LEVEL = "3"

config_df = pd.DataFrame(
    [
        {"key": "model_path", "value": MODEL_PATH},
        {"key": "results_dir", "value": RESULTS_DIR},
        {"key": "force_reeval", "value": FORCE_REEVAL},
        {"key": "batch_size", "value": BATCH_SIZE},
        {"key": "n_eval_sets", "value": len(EVAL_SETS)},
    ]
).set_index("key")
eval_sets_df = pd.DataFrame(EVAL_SETS)
display(config_df)
display(eval_sets_df)
# Out:
#                                                           value
# key
# model_path    ../../models/model-bn-c64-c128-c256-c256-d256....
# results_dir                                 cnn-compare-results
# force_reeval                                              False
# batch_size                                                   16
# n_eval_sets                                                  10
#                name      domain variant  \
# 0        vivo_clean        vivo   clean
# 1        vivo_noise        vivo   noise
# 2    thinkpad_clean    thinkpad   clean
# 3    thinkpad_noise    thinkpad   noise
# 4        flow_clean        flow   clean
# 5        flow_noise        flow   noise
# 6  thinkpad-2_clean  thinkpad-2   clean
# 7  thinkpad-2_noise  thinkpad-2   noise
# 8      flow-2_clean      flow-2   clean
# 9      flow-2_noise      flow-2   noise
#
#                                  features
# 0                                vivo.npz
# 1        vivo-noise-interior_domestic.npz
# 2                            thinkpad.npz
# 3    thinkpad-noise-interior_domestic.npz
# 4                                flow.npz
# 5        flow-noise-interior_domestic.npz
# 6                          thinkpad-2.npz
# 7  thinkpad-2-noise-interior_domestic.npz
# 8                              flow-2.npz
# 9      flow-2-noise-interior_domestic.npz

# %% [markdown]
# ## Setup

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = TF_CPP_MIN_LOG_LEVEL
os.environ["TF_DETERMINISTIC_OPS"] = "1"
os.environ["PYTHONHASHSEED"] = str(RANDOM_STATE)

import random
import numpy as np
import tensorflow as tf
import pandas as pd
from IPython.display import display
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    precision_recall_fscore_support,
)
from sklearn.preprocessing import LabelEncoder
from os import makedirs, path, remove

random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

gpus = tf.config.list_physical_devices("GPU")
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as exc:
        pass

makedirs(CACHE_DIR, exist_ok=True)
makedirs(METRICS_DIR, exist_ok=True)

setup_df = pd.DataFrame(
    [{
        "tensorflow": tf.__version__,
        "gpus": str(gpus),
        "cache_dir": CACHE_DIR,
        "metrics_dir": METRICS_DIR,
    }]
)
display(setup_df)
# Out:
#   tensorflow gpus                  cache_dir                  metrics_dir
# 0     2.15.0   []  cnn-compare-results/cache  cnn-compare-results/metrics

# %% [markdown]
# ## Helpers (cache + metrics)

# %%
def cache_path(name):
    return path.join(CACHE_DIR, f"{name}.npz")


def metrics_path(name):
    return path.join(METRICS_DIR, f"{name}.csv")


def load_class_names():
    with np.load(TRAINING_FEATURES, allow_pickle=True) as train:
        return np.sort(np.unique(np.asarray(train["labels"]).astype(str)))


def compute_metrics(y_true, y_pred, class_names, name, domain, variant):
    acc = accuracy_score(y_true, y_pred)
    p_m, r_m, f_m, _ = precision_recall_fscore_support(
        y_true, y_pred, average="macro", zero_division=0
    )
    p_w, r_w, f_w, _ = precision_recall_fscore_support(
        y_true, y_pred, average="weighted", zero_division=0
    )
    summary = {
        "name": name,
        "domain": domain,
        "variant": variant,
        "n_samples": int(len(y_true)),
        "n_classes": int(len(class_names)),
        "accuracy": float(acc),
        "macro_precision": float(p_m),
        "macro_recall": float(r_m),
        "macro_f1": float(f_m),
        "weighted_precision": float(p_w),
        "weighted_recall": float(r_w),
        "weighted_f1": float(f_w),
    }
    report = classification_report(
        y_true,
        y_pred,
        labels=np.arange(len(class_names)),
        target_names=list(class_names),
        output_dict=True,
        zero_division=0,
    )
    report_df = pd.DataFrame(report).T
    report_df.insert(0, "name", name)
    report_df.insert(1, "domain", domain)
    report_df.insert(2, "variant", variant)
    return summary, report_df


def evaluate_one(spec, model, label_encoder, class_names):
    """Predict + metrics for one pack. Uses cache when available."""
    name = spec["name"]
    feat_path = path.join(FEATURES_DIR, spec["features"])
    cpath = cache_path(name)
    mpath = metrics_path(name)

    if path.isfile(cpath) and path.isfile(mpath) and not FORCE_REEVAL:
        cached = np.load(cpath, allow_pickle=True)
        metrics_df = pd.read_csv(mpath)
        summary = metrics_df.iloc[0].to_dict()
        return {
            "status": "cache_hit",
            "summary": summary,
            "y_true": cached["y_true"],
            "y_pred": cached["y_pred"],
            "labels": cached["labels"].astype(str),
            "class_names": class_names,
            "cache_path": cpath,
            "metrics_path": mpath,
        }

    if not path.isfile(feat_path):
        raise FileNotFoundError(feat_path)

    with np.load(feat_path, allow_pickle=True) as data:
        features = data["features"]
        labels = np.asarray(data["labels"]).astype(str)

    unknown = sorted(set(labels) - set(class_names))
    if unknown:
        raise ValueError(f"{name}: labels not in training classes: {unknown[:5]}")

    y_true = label_encoder.transform(labels)
    x = features
    if x.ndim == 3:
        x = np.expand_dims(x, axis=-1)
    x = x.astype(np.float32, copy=False)

    proba = model.predict(x, batch_size=BATCH_SIZE, verbose=1)
    y_pred = np.argmax(proba, axis=1)

    summary, report_df = compute_metrics(
        y_true, y_pred, class_names, name, spec["domain"], spec["variant"]
    )

    # atomic-ish write: save cache then metrics
    np.savez_compressed(
        cpath,
        y_true=y_true.astype(np.int32),
        y_pred=y_pred.astype(np.int32),
        proba=proba.astype(np.float32),
        labels=labels.astype(str),
        class_names=class_names.astype(str),
        features_path=np.asarray(feat_path),
        model_path=np.asarray(MODEL_PATH),
        domain=np.asarray(spec["domain"]),
        variant=np.asarray(spec["variant"]),
    )
    metrics_df = pd.DataFrame([summary])
    metrics_df.to_csv(mpath, index=False)
    report_df.to_csv(path.join(METRICS_DIR, f"{name}_report.csv"))

    return {
        "status": "computed",
        "summary": summary,
        "y_true": y_true,
        "y_pred": y_pred,
        "labels": labels,
        "class_names": class_names,
        "cache_path": cpath,
        "metrics_path": mpath,
    }


def write_progress(rows):
    pd.DataFrame(rows).to_csv(PROGRESS_PATH, index=False)


display(pd.DataFrame([{"helpers": "ready"}]))
# Out:
#   helpers
# 0   ready

# %% [markdown]
# ## Evaluate (with resume)

# %%
from sklearn.preprocessing import LabelEncoder

assert path.isfile(MODEL_PATH), f"Missing model: {MODEL_PATH}"
assert path.isfile(TRAINING_FEATURES), f"Missing training features: {TRAINING_FEATURES}"
for spec in EVAL_SETS:
    fp = path.join(FEATURES_DIR, spec["features"])
    assert path.isfile(fp), f"Missing features: {fp}"

tf.keras.backend.clear_session()
model = tf.keras.models.load_model(MODEL_PATH)
class_names = load_class_names()
label_encoder = LabelEncoder()
label_encoder.fit(class_names)

model_df = pd.DataFrame(
    [{
        "model_path": MODEL_PATH,
        "input_shape": model.input_shape,
        "output_shape": model.output_shape,
        "n_classes": len(class_names),
    }]
)
display(model_df)

run_results = []
progress_rows = []

for spec in EVAL_SETS:
    result = evaluate_one(spec, model, label_encoder, class_names)
    run_results.append(result)
    row = dict(result["summary"])
    row["status"] = result["status"]
    row["cache_path"] = result["cache_path"]
    progress_rows.append(row)
    write_progress(progress_rows)  # checkpoint after each pack
    display(pd.DataFrame([row])[[
        "name", "domain", "variant", "status", "n_samples",
        "accuracy", "macro_f1", "weighted_f1",
    ]])

progress_df = pd.DataFrame(progress_rows)
display(progress_df[[
    "name", "domain", "variant", "status", "n_samples",
    "accuracy", "macro_precision", "macro_recall", "macro_f1",
]])
# Out:
#                                           model_path          input_shape  \
# 0  ../../models/model-bn-c64-c128-c256-c256-d256....  (None, 216, 188, 1)
#
#   output_shape  n_classes
# 0   (None, 36)         36
#          name domain variant     status  n_samples  accuracy  macro_f1  \
# 0  vivo_clean   vivo   clean  cache_hit       1440  0.945833  0.937388
#
#    weighted_f1
# 0     0.937388
#          name domain variant     status  n_samples  accuracy  macro_f1  \
# 0  vivo_noise   vivo   noise  cache_hit       1440  0.910417  0.898828
#
#    weighted_f1
# 0     0.898828
#              name    domain variant     status  n_samples  accuracy  macro_f1  \
# 0  thinkpad_clean  thinkpad   clean  cache_hit       1440  0.994444  0.994428
#
#    weighted_f1
# 0     0.994428
#              name    domain variant     status  n_samples  accuracy  macro_f1  \
# 0  thinkpad_noise  thinkpad   noise  cache_hit       1440  0.959722   0.96044
#
#    weighted_f1
# 0      0.96044
#          name domain variant     status  n_samples  accuracy  macro_f1  \
# 0  flow_clean   flow   clean  cache_hit       1440  0.888194  0.871271
#
#    weighted_f1
# 0     0.871271
#          name domain variant     status  n_samples  accuracy  macro_f1  \
# 0  flow_noise   flow   noise  cache_hit       1440  0.843056  0.833721
#
#    weighted_f1
# 0     0.833721
#  1/45 [..............................] - ETA: 14s
#  2/45 [>.............................] - ETA: 7s
#  3/45 [=>............................] - ETA: 7s
#  4/45 [=>............................] - ETA: 7s
#  5/45 [==>...........................] - ETA: 6s
#  6/45 [===>..........................] - ETA: 6s
#  7/45 [===>..........................] - ETA: 6s
#  8/45 [====>.........................] - ETA: 6s
#  9/45 [=====>........................] - ETA: 6s
# 10/45 [=====>........................] - ETA: 6s
# 11/45 [======>.......................] - ETA: 5s
# 12/45 [=======>......................] - ETA: 5s
# 13/45 [=======>......................] - ETA: 5s
# 14/45 [========>.....................] - ETA: 5s
# 15/45 [=========>....................] - ETA: 5s
# 16/45 [=========>....................] - ETA: 4s
# 17/45 [==========>...................] - ETA: 4s
# 18/45 [===========>..................] - ETA: 4s
# 19/45 [===========>..................] - ETA: 4s
# 20/45 [============>.................] - ETA: 4s
# 21/45 [=============>................] - ETA: 4s
# 22/45 [=============>................] - ETA: 3s
# 23/45 [==============>...............] - ETA: 3s
# 24/45 [===============>..............] - ETA: 3s
# 25/45 [===============>..............] - ETA: 3s
# 26/45 [================>.............] - ETA: 3s
# 27/45 [=================>............] - ETA: 3s
# 28/45 [=================>............] - ETA: 2s
# 29/45 [==================>...........] - ETA: 2s
# 30/45 [===================>..........] - ETA: 2s
# 31/45 [===================>..........] - ETA: 2s
# 32/45 [====================>.........] - ETA: 2s
# 33/45 [=====================>........] - ETA: 2s
# 34/45 [=====================>........] - ETA: 1s
# 35/45 [======================>.......] - ETA: 1s
# 36/45 [=======================>......] - ETA: 1s
# 37/45 [=======================>......] - ETA: 1s
# 38/45 [========================>.....] - ETA: 1s
# 39/45 [=========================>....] - ETA: 1s
# 40/45 [=========================>....] - ETA: 0s
# 41/45 [==========================>...] - ETA: 0s
# 62/90 [===================>..........] - ETA: 4s
# 63/90 [====================>.........] - ETA: 4s
# 64/90 [====================>.........] - ETA: 4s
# 65/90 [====================>.........] - ETA: 4s
# 66/90 [=====================>........] - ETA: 4s
# 67/90 [=====================>........] - ETA: 3s
# 68/90 [=====================>........] - ETA: 3s
# 69/90 [======================>.......] - ETA: 3s
# 70/90 [======================>.......] - ETA: 3s
# 71/90 [======================>.......] - ETA: 3s
# 72/90 [=======================>......] - ETA: 3s
# 73/90 [=======================>......] - ETA: 2s
# 74/90 [=======================>......] - ETA: 2s
# 75/90 [========================>.....] - ETA: 2s
# 76/90 [========================>.....] - ETA: 2s
# 77/90 [========================>.....] - ETA: 2s
# 78/90 [=========================>....] - ETA: 2s
# 79/90 [=========================>....] - ETA: 1s
# 80/90 [=========================>....] - ETA: 1s
# 81/90 [==========================>...] - ETA: 1s
# 82/90 [==========================>...] - ETA: 1s
# 83/90 [==========================>...] - ETA: 1s
# 84/90 [===========================>..] - ETA: 1s
# 85/90 [===========================>..] - ETA: 0s
# 86/90 [===========================>..] - ETA: 0s
# 87/90 [============================>.] - ETA: 0s
# 88/90 [============================>.] - ETA: 0s
# 89/90 [============================>.] - ETA: 0s
# 90/90 [==============================] - ETA: 0s
# 90/90 [==============================] - 15s 169ms/step
#            name  domain variant    status  n_samples  accuracy  macro_f1  \
# 0  flow-2_noise  flow-2   noise  computed       1440  0.841667  0.817305
#
#    weighted_f1
# 0     0.817305
#                name      domain variant     status  n_samples  accuracy  \
# 0        vivo_clean        vivo   clean  cache_hit       1440  0.945833
# 1        vivo_noise        vivo   noise  cache_hit       1440  0.910417
# 2    thinkpad_clean    thinkpad   clean  cache_hit       1440  0.994444
# 3    thinkpad_noise    thinkpad   noise  cache_hit       1440  0.959722
# 4        flow_clean        flow   clean  cache_hit       1440  0.888194
# 5        flow_noise        flow   noise  cache_hit       1440  0.843056
# 6  thinkpad-2_clean  thinkpad-2   clean   computed        720  0.876389
# 7  thinkpad-2_noise  thinkpad-2   noise   computed        720  0.850000
# 8      flow-2_clean      flow-2   clean   computed       1440  0.874306
# 9      flow-2_noise      flow-2   noise   computed       1440  0.841667
#
#    macro_precision  macro_recall  macro_f1
# 0         0.949536      0.945833  0.937388
# 1         0.911559      0.910417  0.898828
# 2         0.994976      0.994444  0.994428
# 3         0.967151      0.959722  0.960440
# 4         0.907633      0.888194  0.871271
# 5         0.895896      0.843056  0.833721
# 6         0.843144      0.876389  0.846607
# 7         0.881958      0.850000  0.831170
# 8         0.848498      0.874306  0.840170
# 9         0.885000      0.841667  0.817305

# %% [markdown]
# ## Comparison tables

# %%
# Rebuild summary from caches (safe if re-run without re-predict)
rows = []
for spec in EVAL_SETS:
    mpath = metrics_path(spec["name"])
    if not path.isfile(mpath):
        continue
    df = pd.read_csv(mpath)
    rows.append(df.iloc[0].to_dict())

summary_df = pd.DataFrame(rows)
summary_df.to_csv(SUMMARY_PATH, index=False)

# Wide comparison: clean vs noise per domain
wide = summary_df.pivot(index="domain", columns="variant", values=[
    "accuracy", "macro_f1", "weighted_f1", "n_samples"
])
# Flatten multiindex columns for readability
wide.columns = [f"{metric}_{variant}" for metric, variant in wide.columns]
wide = wide.reset_index()

# Deltas (noise - clean): negative = noise hurts
for metric in ["accuracy", "macro_f1", "weighted_f1"]:
    ccol, ncol = f"{metric}_clean", f"{metric}_noise"
    if ccol in wide.columns and ncol in wide.columns:
        wide[f"delta_{metric}"] = wide[ncol] - wide[ccol]

display(summary_df.sort_values(["domain", "variant"]).reset_index(drop=True))
display(wide)

wide.to_csv(path.join(RESULTS_DIR, "summary_wide.csv"), index=False)
display(pd.DataFrame([{"summary_path": SUMMARY_PATH, "wide_path": path.join(RESULTS_DIR, "summary_wide.csv")}]))
# Out:
#                name      domain variant  n_samples  n_classes  accuracy  \
# 0        flow_clean        flow   clean       1440         36  0.888194
# 1        flow_noise        flow   noise       1440         36  0.843056
# 2      flow-2_clean      flow-2   clean       1440         36  0.874306
# 3      flow-2_noise      flow-2   noise       1440         36  0.841667
# 4    thinkpad_clean    thinkpad   clean       1440         36  0.994444
# 5    thinkpad_noise    thinkpad   noise       1440         36  0.959722
# 6  thinkpad-2_clean  thinkpad-2   clean        720         36  0.876389
# 7  thinkpad-2_noise  thinkpad-2   noise        720         36  0.850000
# 8        vivo_clean        vivo   clean       1440         36  0.945833
# 9        vivo_noise        vivo   noise       1440         36  0.910417
#
#    macro_precision  macro_recall  macro_f1  weighted_precision  \
# 0         0.907633      0.888194  0.871271            0.907633
# 1         0.895896      0.843056  0.833721            0.895896
# 2         0.848498      0.874306  0.840170            0.848498
# 3         0.885000      0.841667  0.817305            0.885000
# 4         0.994976      0.994444  0.994428            0.994976
# 5         0.967151      0.959722  0.960440            0.967151
# 6         0.843144      0.876389  0.846607            0.843144
# 7         0.881958      0.850000  0.831170            0.881958
# 8         0.949536      0.945833  0.937388            0.949536
# 9         0.911559      0.910417  0.898828            0.911559
#
#    weighted_recall  weighted_f1
# 0         0.888194     0.871271
# 1         0.843056     0.833721
# 2         0.874306     0.840170
# 3         0.841667     0.817305
# 4         0.994444     0.994428
# 5         0.959722     0.960440
# 6         0.876389     0.846607
# 7         0.850000     0.831170
# 8         0.945833     0.937388
# 9         0.910417     0.898828
#        domain  accuracy_clean  accuracy_noise  macro_f1_clean  macro_f1_noise  \
# 0        flow        0.888194        0.843056        0.871271        0.833721
# 1      flow-2        0.874306        0.841667        0.840170        0.817305
# 2    thinkpad        0.994444        0.959722        0.994428        0.960440
# 3  thinkpad-2        0.876389        0.850000        0.846607        0.831170
# 4        vivo        0.945833        0.910417        0.937388        0.898828
#
#    weighted_f1_clean  weighted_f1_noise  n_samples_clean  n_samples_noise  \
# 0           0.871271           0.833721           1440.0           1440.0
# 1           0.840170           0.817305           1440.0           1440.0
# 2           0.994428           0.960440           1440.0           1440.0
# 3           0.846607           0.831170            720.0            720.0
# 4           0.937388           0.898828           1440.0           1440.0
#
#    delta_accuracy  delta_macro_f1  delta_weighted_f1
# 0       -0.045139       -0.037550          -0.037550
# 1       -0.032639       -0.022865          -0.022865
# 2       -0.034722       -0.033988          -0.033988
# 3       -0.026389       -0.015437          -0.015437
# 4       -0.035417       -0.038559          -0.038559
#                       summary_path                             wide_path
# 0  cnn-compare-results/summary.csv  cnn-compare-results/summary_wide.csv

# %% [markdown]
# ## Per-class clean vs noise

# %%
from sklearn.metrics import recall_score

perclass_frames = []
for spec in EVAL_SETS:
    cpath = cache_path(spec["name"])
    if not path.isfile(cpath):
        continue
    cached = np.load(cpath, allow_pickle=True)
    y_true = cached["y_true"]
    y_pred = cached["y_pred"]
    names = cached["class_names"].astype(str)
    recalls = recall_score(
        y_true, y_pred, labels=np.arange(len(names)), average=None, zero_division=0
    )
    perclass_frames.append(pd.DataFrame({
        "domain": spec["domain"],
        "variant": spec["variant"],
        "class": names,
        "recall": recalls,
        "support": np.bincount(y_true, minlength=len(names)),
    }))

perclass_long = pd.concat(perclass_frames, ignore_index=True)

# Pivot to clean/noise columns per domain+class
perclass_wide = perclass_long.pivot_table(
    index=["domain", "class"],
    columns="variant",
    values="recall",
    aggfunc="first",
).reset_index()
perclass_wide.columns.name = None
if "clean" in perclass_wide.columns and "noise" in perclass_wide.columns:
    perclass_wide["delta_recall"] = perclass_wide["noise"] - perclass_wide["clean"]

perclass_wide.to_csv(PERCLASS_PATH, index=False)

# Show largest drops under noise (most hurt classes)
for domain in sorted(perclass_wide["domain"].unique()):
    sub = perclass_wide[perclass_wide["domain"] == domain].copy()
    if "delta_recall" in sub.columns:
        sub = sub.sort_values("delta_recall").head(10)
    display(pd.DataFrame([{"domain": domain, "note": "top-10 largest recall drops (noise − clean)"}]))
    display(sub.reset_index(drop=True))

display(pd.DataFrame([{"perclass_path": PERCLASS_PATH, "n_rows": len(perclass_wide)}]))
# Out:
#   domain                                         note
# 0   flow  top-10 largest recall drops (noise − clean)
#   domain           class  clean  noise  delta_recall
# 0   flow       C_major_4  0.975  0.625        -0.350
# 1   flow       B_major_4  0.900  0.700        -0.200
# 2   flow       D_major_4  1.000  0.800        -0.200
# 3   flow      G#_minor_4  0.975  0.800        -0.175
# 4   flow      A#_major_4  0.975  0.850        -0.125
# 5   flow      C#_major_4  1.000  0.900        -0.100
# 6   flow      D#_minor_4  1.000  0.900        -0.100
# 7   flow  F_diminished_4  0.950  0.850        -0.100
# 8   flow       D_minor_4  0.175  0.100        -0.075
# 9   flow       G_major_4  1.000  0.925        -0.075
#    domain                                         note
# 0  flow-2  top-10 largest recall drops (noise − clean)
#    domain           class  clean  noise  delta_recall
# 0  flow-2       C_major_4  1.000  0.725        -0.275
# 1  flow-2      G#_minor_4  0.875  0.625        -0.250
# 2  flow-2       D_major_4  1.000  0.800        -0.200
# 3  flow-2      D#_minor_4  1.000  0.875        -0.125
# 4  flow-2       E_minor_4  1.000  0.900        -0.100
# 5  flow-2  A_diminished_4  1.000  0.925        -0.075
# 6  flow-2      F#_major_4  1.000  0.950        -0.050
# 7  flow-2  F_diminished_4  1.000  0.950        -0.050
# 8  flow-2      G#_major_4  1.000  0.950        -0.050
# 9  flow-2       A_major_4  1.000  0.950        -0.050
#      domain                                         note
# 0  thinkpad  top-10 largest recall drops (noise − clean)
#      domain           class  clean  noise  delta_recall
# 0  thinkpad       C_major_4  0.875  0.675        -0.200
# 1  thinkpad  E_diminished_4  0.925  0.800        -0.125
# 2  thinkpad       B_major_4  1.000  0.875        -0.125
# 3  thinkpad       B_minor_4  1.000  0.900        -0.100
# 4  thinkpad      D#_minor_4  1.000  0.925        -0.075
# 5  thinkpad      C#_major_4  1.000  0.925        -0.075
# 6  thinkpad       G_minor_4  1.000  0.925        -0.075
# 7  thinkpad      F#_major_4  1.000  0.950        -0.050
# 8  thinkpad       A_major_4  1.000  0.950        -0.050
# 9  thinkpad       D_minor_4  1.000  0.950        -0.050
#        domain                                         note
# 0  thinkpad-2  top-10 largest recall drops (noise − clean)
#        domain           class  clean  noise  delta_recall
# 0  thinkpad-2       C_major_4   0.95   0.65         -0.30
# 1  thinkpad-2       G_major_4   1.00   0.80         -0.20
# 2  thinkpad-2      A#_major_4   1.00   0.85         -0.15
# 3  thinkpad-2      G#_minor_4   1.00   0.85         -0.15
# 4  thinkpad-2      D#_minor_4   1.00   0.90         -0.10
# 5  thinkpad-2      F#_minor_4   1.00   0.90         -0.10
# 6  thinkpad-2       D_major_4   1.00   0.90         -0.10
# 7  thinkpad-2  F_diminished_4   1.00   0.95         -0.05
# 8  thinkpad-2  A_diminished_4   1.00   0.95         -0.05
# 9  thinkpad-2      C#_minor_4   1.00   0.95         -0.05
#   domain                                         note
# 0   vivo  top-10 largest recall drops (noise − clean)
#   domain           class  clean  noise  delta_recall
# 0   vivo       G_minor_4  0.825  0.625        -0.200
# 1   vivo       B_major_4  1.000  0.850        -0.150
# 2   vivo       D_minor_4  1.000  0.900        -0.100
# 3   vivo  G_diminished_4  0.975  0.900        -0.075
# 4   vivo       F_major_4  1.000  0.925        -0.075
# 5   vivo       B_minor_4  0.975  0.900        -0.075
# 6   vivo  F_diminished_4  1.000  0.950        -0.050
# 7   vivo      D#_major_4  1.000  0.950        -0.050
# 8   vivo      C#_major_4  1.000  0.950        -0.050
# 9   vivo      D#_minor_4  1.000  0.950        -0.050
#                                  perclass_path  n_rows
# 0  cnn-compare-results/perclass_comparison.csv     180

# %% [markdown]
# ## Summary bar chart

# %%
import matplotlib.pyplot as plt

plot_df = summary_df.copy()
plot_df["label"] = plot_df["domain"] + " / " + plot_df["variant"]
plot_df = plot_df.sort_values(["domain", "variant"]).reset_index(drop=True)

fig, ax = plt.subplots(figsize=(9, 5))
x = np.arange(len(plot_df))
colors = ["#4C78A8" if v == "clean" else "#F58518" for v in plot_df["variant"]]
bars = ax.bar(x, plot_df["accuracy"], color=colors, edgecolor="black", linewidth=0.4)

ax.set_xticks(x)
ax.set_xticklabels(plot_df["label"], rotation=20, ha="right")
ax.set_ylabel("Accuracy")
ax.set_ylim(0, 1.18)  # headroom so value labels don't hit the title
ax.set_title(
    "CNN accuracy: clean vs noise (interior_domestic mix)",
    pad=16,
)

for i, (acc, f1) in enumerate(zip(plot_df["accuracy"], plot_df["macro_f1"])):
    ax.text(
        i,
        acc + 0.03,
        f"{acc:.3f}\nF1={f1:.3f}",
        ha="center",
        va="bottom",
        fontsize=9,
    )

fig.subplots_adjust(top=0.88, bottom=0.22)
bar_path = path.join(RESULTS_DIR, "accuracy_clean_vs_noise.png")
fig.savefig(bar_path, dpi=150, bbox_inches="tight")
plt.show()

display(pd.DataFrame([{"bar_chart": bar_path}]))
# Out:
#                                          bar_chart
# 0  cnn-compare-results/accuracy_clean_vs_noise.png

# %% [markdown]
# ## Confusion matrices
#
# One matrix per eval pack (clean and noise). Saved under `cnn-compare-results/confusion/`.

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

CM_DIR = path.join(RESULTS_DIR, "confusion")
makedirs(CM_DIR, exist_ok=True)

cm_rows = []
for spec in EVAL_SETS:
    name = spec["name"]
    cpath = cache_path(name)
    if not path.isfile(cpath):
        continue
    cached = np.load(cpath, allow_pickle=True)
    y_true = cached["y_true"]
    y_pred = cached["y_pred"]
    class_names = cached["class_names"].astype(str)

    cm = confusion_matrix(y_true, y_pred, labels=np.arange(len(class_names)))
    cm_df = pd.DataFrame(cm, index=class_names, columns=class_names)
    csv_path = path.join(CM_DIR, f"{name}.csv")
    png_path = path.join(CM_DIR, f"{name}.png")
    cm_df.to_csv(csv_path)

    fig, ax = plt.subplots(figsize=(16, 14))
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=class_names,
        yticklabels=class_names,
        ax=ax,
    )
    ax.set_xlabel("Predicted Label")
    ax.set_ylabel("True Label")
    acc = float(summary_df.loc[summary_df["name"] == name, "accuracy"].iloc[0])
    ax.set_title(
        f"CNN confusion — {name} (acc={acc:.3f})",
        pad=12,
    )
    fig.tight_layout()
    fig.savefig(png_path, dpi=150, bbox_inches="tight")
    plt.show()

    cm_rows.append({
        "name": name,
        "domain": spec["domain"],
        "variant": spec["variant"],
        "accuracy": acc,
        "csv": csv_path,
        "png": png_path,
    })

display(pd.DataFrame(cm_rows))
# Out:
#                name      domain variant  accuracy  \
# 0        vivo_clean        vivo   clean  0.945833
# 1        vivo_noise        vivo   noise  0.910417
# 2    thinkpad_clean    thinkpad   clean  0.994444
# 3    thinkpad_noise    thinkpad   noise  0.959722
# 4        flow_clean        flow   clean  0.888194
# 5        flow_noise        flow   noise  0.843056
# 6  thinkpad-2_clean  thinkpad-2   clean  0.876389
# 7  thinkpad-2_noise  thinkpad-2   noise  0.850000
# 8      flow-2_clean      flow-2   clean  0.874306
# 9      flow-2_noise      flow-2   noise  0.841667
#
#                                                  csv  \
# 0       cnn-compare-results/confusion/vivo_clean.csv
# 1       cnn-compare-results/confusion/vivo_noise.csv
# 2   cnn-compare-results/confusion/thinkpad_clean.csv
# 3   cnn-compare-results/confusion/thinkpad_noise.csv
# 4       cnn-compare-results/confusion/flow_clean.csv
# 5       cnn-compare-results/confusion/flow_noise.csv
# 6  cnn-compare-results/confusion/thinkpad-2_clean...
# 7  cnn-compare-results/confusion/thinkpad-2_noise...
# 8     cnn-compare-results/confusion/flow-2_clean.csv
# 9     cnn-compare-results/confusion/flow-2_noise.csv
#
#                                                  png
# 0       cnn-compare-results/confusion/vivo_clean.png
# 1       cnn-compare-results/confusion/vivo_noise.png
# 2   cnn-compare-results/confusion/thinkpad_clean.png
# 3   cnn-compare-results/confusion/thinkpad_noise.png
# 4       cnn-compare-results/confusion/flow_clean.png
# 5       cnn-compare-results/confusion/flow_noise.png
# 6  cnn-compare-results/confusion/thinkpad-2_clean...
# 7  cnn-compare-results/confusion/thinkpad-2_noise...
# 8     cnn-compare-results/confusion/flow-2_clean.png
# 9     cnn-compare-results/confusion/flow-2_noise.png
